# %%
import pandas as pd
from bs4 import BeautifulSoup as BS
import requests
import urllib3

# %%
pg_2016 = 154
pg_2017 = 147
pg_2018 = 85
pg_2019 = 113
pg_half_2016 = 898
pg_half_2017 = 892
pg_half_2018 = 598
pg_half_2019 = 690

url_2019 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2019-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
url_2018 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2018-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
url_2017 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2017-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
url_2016 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2016-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
url_half_2019 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Half-Marathon/2019-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
url_half_2018 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Half-Marathon/2018-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
url_half_2017 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Half-Marathon/2017-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
url_half_2016 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Half-Marathon/2016-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='

# %%
marathon2019_df = pd.DataFrame(columns = ['Overall','Bib','Name','Time'])
marathon2018_df = pd.DataFrame(columns = ['Overall','Bib','Name','Time'])
marathon2017_df = pd.DataFrame(columns = ['Overall','Bib','Name','Time'])
marathon2016_df = pd.DataFrame(columns = ['Overall','Bib','Name','Time'])
half_marathon2019_df = pd.DataFrame(columns = ['Overall','Bib','Name','Time'])
half_marathon2019_df = pd.DataFrame(columns = ['Overall','Bib','Name','Time'])
half_marathon2019_df = pd.DataFrame(columns = ['Overall','Bib','Name','Time'])
half_marathon2019_df = pd.DataFrame(columns = ['Overall','Bib','Name','Time'])

# %%
base = url_2019
page = 17
url = base + str(page)

# %%
url
# Out:
# 'https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2019-Results?gender=&agegroup=&bib=&firstname=&lastname=&page=17'

# %%
result = requests.post(url)
result.text
# Out:
# '\n<!DOCTYPE html>\n<!--[if IE 9]><html lang="en" class="ie9 no-js"><![endif]-->\n<!--[if !IE]><!-->\n<html lang="en">\n<!--<![endif]-->\n<head>\n<script src="/cdn-cgi/apps/head/7FoXDn8p6JbK9hG0NSbLyMKO0Zg.js"></script><link href="/styles/vendor.min.css" rel="stylesheet" />\n<link href="/styles/rnr.min.css" rel="stylesheet" />\n<meta charset="utf-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta http-equiv="Content-type" content="text/html; charset=utf-8">\n<meta content="width=device-width, initial-scale=1.0" name="viewport" />\n<title> | Rock n Roll Marathon Series | Marathon Half Marathon Events</title>\n<meta property="og:title" content="" />\n<meta property="og:image" content="" />\n<meta property="og:description" content="" />\n<meta property="og:url" content="https://www.runrocknroll.com:443/en/Events/Nashville/The Races/Marathon/2019 Results" />\n\n<script>\r\n        (function (w, d, s, l, i) {\r\n            w[l] = w[l] || [];\r\n            w[l].push({\r\
# ...

# %%
soup = BS(result.text, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <!--[if IE 9]><html lang="en" class="ie9 no-js"><![endif]--><!--[if !IE]><!--><html lang="en">
# <!--<![endif]-->
# <head>
# <script src="/cdn-cgi/apps/head/7FoXDn8p6JbK9hG0NSbLyMKO0Zg.js"></script><link href="/styles/vendor.min.css" rel="stylesheet"/>
# <link href="/styles/rnr.min.css" rel="stylesheet"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title> | Rock n Roll Marathon Series | Marathon Half Marathon Events</title>
# <meta content="" property="og:title"/>
# <meta content="" property="og:image"/>
# <meta content="" property="og:description"/>
# <meta content="https://www.runrocknroll.com:443/en/Events/Nashville/The Races/Marathon/2019 Results" property="og:url"/>
# <script>
#         (function (w, d, s, l, i) {
#             w[l] = w[l] || [];
#             w[l].push({
# ...

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
tables = soup.find_all('table', attrs = {'class':"table table-responsive table-bordered"})

# %%
result_list = pd.read_html(str(tables[0]))#returns a list of Dataframes

# %%
df_2019 = pd.DataFrame(result_list[0])

# %%
df_2019.shape
# Out:
# (25, 4)

# %%
pd.read_html(str(tables[0]))
# Out:
# [    Overall    Bib               Name      Time
#  0       401  31179         Denis Osin  03:59:34
#  1       402  31180        Maria Osina  03:59:35
#  2       403  31575       Clare Hickey  03:59:39
#  3       404  31388   Zachary Peterson  03:59:46
#  4       405  33016       Hunter Hicks  03:59:50
#  5       406  30360     Matthew Mclure  03:59:51
#  6       407  30012         Sam Mccord  03:59:53
#  7       408  30560          Cora Cope  04:00:03
#  8       409  30855     Rosie Arellano  04:00:07
#  9       410  30417          Zac Walsh  04:00:11
#  10      411  30901      Jody Campbell  04:00:17
#  11      412  30473     Nicholas Clark  04:00:18
#  12      413  31323        Ella Wright  04:00:19
#  13      414  30614     Amanda Klopfer  04:00:29
#  14      415  30543        Cody Bascom  04:00:43
#  15      416  31275  Mitsuru Takahashi  04:00:44
#  16      417  30520     Zachary Warren  04:00:48
#  17      418  30566     Kelsey Crowley  04:00:52
# ...

# %%
marathon2019_df = pd.DataFrame(columns = ['Overall','Bib','Name','Time'])
for page in range(1, 1+pg_2019):
    marathon2019_df = marathon2019_df.append(df_2019)

# %%
marathon2019_df.head()
# Out:
#   Overall    Bib              Name      Time
# 0     401  31179        Denis Osin  03:59:34
# 1     402  31180       Maria Osina  03:59:35
# 2     403  31575      Clare Hickey  03:59:39
# 3     404  31388  Zachary Peterson  03:59:46
# 4     405  33016      Hunter Hicks  03:59:50

# %%
df_2019.tail()
# Out:
#     Overall    Bib         Name      Time
# 20      421  30134  Peter Euler  04:01:08
# 21      422  33100   Ben Hughes  04:01:15
# 22      423  30028    Nghiem Le  04:01:21
# 23      424  31259  David Smith  04:01:29
# 24      425  30687   Eric Yeats  04:01:30

# %%
marathon2019_df.shape
# Out:
# (2825, 4)

# %%
marathon2018_df = pd.DataFrame(columns = ['Overall','Bib','Name','Time'])
for page in range(1, 1+ pg_2018):
    url = url_2018
    result = requests.post(url)
    soup = BS(result.text, 'lxml')
    tables = soup.find_all('table', attrs = {'class':"table table-responsive table-bordered"})
    result_list = pd.read_html(str(tables[0]))
    df = pd.DataFrame(result_list[0])
    marathon2018_df  = marathon2018_df.append(df)

# %%
marathon2018_df.shape
# Out:
# (2125, 4)

# %%
marathon2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2125 entries, 0 to 24
# Data columns (total 4 columns):
# Overall    2125 non-null object
# Bib        2125 non-null object
# Name       2125 non-null object
# Time       2125 non-null object
# dtypes: object(4)
# memory usage: 83.0+ KB

# %%
marathon2018_df.head()
# Out:
#   Overall    Bib             Name      Time
# 0       1      1   Scott Wietecha  02:28:16
# 1       2      3     Garang Madut  02:29:52
# 2       3  33442       Kevin Fink  02:38:59
# 3       4  33441    Andrew Hodges  02:43:59
# 4       5  30028  Nicholas Aubert  02:48:11

# %%
marathon2017_df = pd.DataFrame(columns = ['Overall','Bib','Name','Time'])
for page in range(1, 1+ pg_2017):
    url = url_2017
    result = requests.post(url)
    soup = BS(result.text, 'lxml')
    tables = soup.find_all('table', attrs = {'class':"table table-responsive table-bordered"})
    result_list = pd.read_html(str(tables[0]))
    df = pd.DataFrame(result_list[0])
    marathon2017_df  = marathon2017_df .append(df)

# %%
marathon2017_df.shape
# Out:
# (3675, 4)

# %%
marathon2017_df.head()
# Out:
#   Overall   Bib            Name      Time
# 0       1     1  Scott Wietecha  02:40:25
# 1       2  1145    Ryan Regnier  02:56:28
# 2       3  1147  Daniel Everett  03:00:55
# 3       4  1029   Khris Vickroy  03:04:47
# 4       5  1119  Marcus Dilallo  03:04:53

# %%
marathon2016_df = pd.DataFrame(columns = ['Overall','Bib','Name','Time'])
for page in range(1, 1+ pg_2016):
    url = url_2016
    result = requests.post(url)
    soup = BS(result.text, 'lxml')
    tables = soup.find_all('table', attrs = {'class':"table table-responsive table-bordered"})
    result_list = pd.read_html(str(tables[0]))
    df = pd.DataFrame(result_list[0])
    marathon2016_df  = marathon2016_df .append(df)

# %%
marathon2016_df.shape
# Out:
# (3850, 4)

# %%
marathon2016_df.head()
# Out:
#   Overall   Bib               Name      Time
# 0       1     1     Scott Wietecha  02:25:42
# 1       2     3      Brian Shelton  02:34:43
# 2       3  1047  Christopher Capps  02:38:43
# 3       4  1052       Jason Grimes  02:45:06
# 4       5  1046        David Adams  02:47:28

# %% [markdown]
# Now Read all the half Marathons

# %%
half_marathon2019_df = pd.DataFrame(columns = ['Overall','Bib','Name','Time'])
for page in range(1, 1+ pg_half_2019):
    url = url_2019
    result = requests.post(url)
    soup = BS(result.text, 'lxml')
    tables = soup.find_all('table', attrs = {'class':"table table-responsive table-bordered"})
    result_list = pd.read_html(str(tables[0]))
    df = pd.DataFrame(result_list[0])
    half_marathon2019_df  = half_marathon2019_df .append(df)

# %%
half_marathon2019_df.shape
# Out:
# (17250, 4)

# %%
half_marathon2019_df.head()
# Out:
#   Overall    Bib            Name      Time
# 0       1  30001  Travis Peruski  01:37:54
# 1       2      1  Scott Wietecha  02:34:59
# 2       3      4   Jordan Wilson  02:35:24
# 3       4  30034  Steelton Flynn  02:39:59
# 4       5  30035    Thomas Ellis  02:42:09

# %%
half_marathon2018_df = pd.DataFrame(columns = ['Overall','Bib','Name','Time'])
for page in range(1, 1+ pg_half_2018):
    url = url_2018
    result = requests.post(url)
    soup = BS(result.text, 'lxml')
    tables = soup.find_all('table', attrs = {'class':"table table-responsive table-bordered"})
    result_list = pd.read_html(str(tables[0]))
    df = pd.DataFrame(result_list[0])
    half_marathon2018_df  = half_marathon2018_df .append(df)

# %%
half_marathon2018_df.shape
# Out:
# (14950, 4)

# %%
half_marathon2018_df.head()
# Out:
#   Overall    Bib             Name      Time
# 0       1      1   Scott Wietecha  02:28:16
# 1       2      3     Garang Madut  02:29:52
# 2       3  33442       Kevin Fink  02:38:59
# 3       4  33441    Andrew Hodges  02:43:59
# 4       5  30028  Nicholas Aubert  02:48:11

# %%
half_marathon2017_df = pd.DataFrame(columns = ['Overall','Bib','Name','Time'])
for page in range(1, 1+ pg_half_2017):
    url = url_2017
    result = requests.post(url)
    soup = BS(result.text, 'lxml')
    tables = soup.find_all('table', attrs = {'class':"table table-responsive table-bordered"})
    result_list = pd.read_html(str(tables[0]))
    df = pd.DataFrame(result_list[0])
    half_marathon2017_df  = half_marathon2017_df .append(df)

# %%
half_marathon2017_df.shape
# Out:
# (22300, 4)

# %%
half_marathon2017_df.head()
# Out:
#   Overall   Bib            Name      Time
# 0       1     1  Scott Wietecha  02:40:25
# 1       2  1145    Ryan Regnier  02:56:28
# 2       3  1147  Daniel Everett  03:00:55
# 3       4  1029   Khris Vickroy  03:04:47
# 4       5  1119  Marcus Dilallo  03:04:53

# %%
half_marathon2016_df = pd.DataFrame(columns = ['Overall','Bib','Name','Time'])
for page in range(1, 1+ pg_half_2016):
    url = url_2016
    result = requests.post(url)
    soup = BS(result.text, 'lxml')
    tables = soup.find_all('table', attrs = {'class':"table table-responsive table-bordered"})
    result_list = pd.read_html(str(tables[0]))
    df = pd.DataFrame(result_list[0])
    half_marathon2016_df  = half_marathon2016_df .append(df)

# %%
half_marathon2016_df.shape
# Out:
# (22450, 4)

# %%
half_marathon2016_df.head()
# Out:
#   Overall   Bib               Name      Time
# 0       1     1     Scott Wietecha  02:25:42
# 1       2     3      Brian Shelton  02:34:43
# 2       3  1047  Christopher Capps  02:38:43
# 3       4  1052       Jason Grimes  02:45:06
# 4       5  1046        David Adams  02:47:28

# %%
marathon2019_df['year'] = 2019

# %%
marathon2018_df['year'] = 2018

# %%
marathon2017_df['year'] = 2017

# %%
marathon2016_df['year'] = 2016

# %%
marathon2017_df.head()
# Out:
#   Overall   Bib            Name      Time  year
# 0       1     1  Scott Wietecha  02:40:25  2017
# 1       2  1145    Ryan Regnier  02:56:28  2017
# 2       3  1147  Daniel Everett  03:00:55  2017
# 3       4  1029   Khris Vickroy  03:04:47  2017
# 4       5  1119  Marcus Dilallo  03:04:53  2017

# %%
#Concatenation all the full marathons
full_df = pd.concat([marathon2016_df,marathon2017_df,marathon2018_df,marathon2019_df],ignore_index=True)

# %%
full_df.head()
# Out:
#   Overall   Bib               Name      Time  year
# 0       1     1     Scott Wietecha  02:25:42  2016
# 1       2     3      Brian Shelton  02:34:43  2016
# 2       3  1047  Christopher Capps  02:38:43  2016
# 3       4  1052       Jason Grimes  02:45:06  2016
# 4       5  1046        David Adams  02:47:28  2016

# %%
full_df.tail()
# Out:
#       Overall    Bib         Name      Time  year
# 12470     421  30134  Peter Euler  04:01:08  2019
# 12471     422  33100   Ben Hughes  04:01:15  2019
# 12472     423  30028    Nghiem Le  04:01:21  2019
# 12473     424  31259  David Smith  04:01:29  2019
# 12474     425  30687   Eric Yeats  04:01:30  2019

# %%
half_marathon2016_df['year']=2016

# %%
half_marathon2017_df['year']=2017

# %%
half_marathon2018_df['year']=2018

# %%
half_marathon2019_df['year']=2019

# %%
half_marathon2016_df.head()
# Out:
#   Overall   Bib               Name      Time  year
# 0       1     1     Scott Wietecha  02:25:42  2016
# 1       2     3      Brian Shelton  02:34:43  2016
# 2       3  1047  Christopher Capps  02:38:43  2016
# 3       4  1052       Jason Grimes  02:45:06  2016
# 4       5  1046        David Adams  02:47:28  2016

# %%
## Concatenating all the half marathons
half_df = pd.concat([half_marathon2016_df,half_marathon2017_df,half_marathon2018_df,half_marathon2019_df],ignore_index=True)
half_df.head()
# Out:
#   Overall   Bib               Name      Time  year
# 0       1     1     Scott Wietecha  02:25:42  2016
# 1       2     3      Brian Shelton  02:34:43  2016
# 2       3  1047  Christopher Capps  02:38:43  2016
# 3       4  1052       Jason Grimes  02:45:06  2016
# 4       5  1046        David Adams  02:47:28  2016

# %%
half_df.tail()
# Out:
#       Overall    Bib                Name      Time  year
# 76945      21  30075          Eddie Bell  03:03:12  2019
# 76946      22  30039  Montana Klingsporn  03:03:17  2019
# 76947      23      2      Mathias Osmark  03:04:01  2019
# 76948      24  30052          Sean Kunis  03:05:22  2019
# 76949      25  30074      Dylan Beaulieu  03:05:28  2019

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12475 entries, 0 to 12474
# Data columns (total 5 columns):
# Overall    12475 non-null object
# Bib        12475 non-null object
# Name       12475 non-null object
# Time       12475 non-null datetime64[ns]
# year       12475 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 487.4+ KB

# %%
full_df['Time']=pd.to_datetime(full_df.Time)

# %%
half_df['Time']=pd.to_datetime(half_df.Time)

# %%
half_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76950 entries, 0 to 76949
# Data columns (total 5 columns):
# Overall    76950 non-null object
# Bib        76950 non-null object
# Name       76950 non-null object
# Time       76950 non-null datetime64[ns]
# year       76950 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.9+ MB
